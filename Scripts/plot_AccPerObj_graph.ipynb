# %%
import Window_Size

import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
# %matplotlib qt5
# %load_ext autoreload
# %autoreload 2
import numpy as np

import Post_Processing
pp = Post_Processing.PP()

# %%
original_results = pp.read_file(fileName='saved results\\1031_AccPerObj.pkl')

# %%
print(original_results)
# Out:
# {'BASE': [[{'Menu': {'windowSize': 20, 'getRawData': 'no', 'doublingData': 'no', 'stage': '1', 'rangeIndex': '-1', 'avgTrials': 'no', 'avgNum': '4', 'normType': 'sk', 'turnOnMeanRemoval': 'no', 'turnOnSliceWindow': 'yes', 'sliceWindowType': 'cf', 'cfDegree': '1', 'baseOrFlip': 'base', 'turnOnPga': 'no', 'newTDT': 'clustered1', 'pcaOn': 'no', 'pcaComponents': '0.9'}, 'Accuracy_Name_linear': 0.3333333333333333, 'Accuracy_Category_linear': 0.7333333333333333, 'Accuracy_Name_rbf': 0.38333333333333336, 'Accuracy_Category_rbf': 0.6, 'Accuracy_Name_lda': 0.3, 'Accuracy_Category_lda': 0.6333333333333333, 'Accuracy_Name_rvm': 0.2833333333333333, 'Accuracy_Category_rvm': 0.6333333333333333, 'Accuracy_Name_gnb': 0.3333333333333333, 'Accuracy_Category_gnb': 0.6666666666666666, 'Accuracy_Name_linear_random': 0.1, 'Accuracy_Category_linear_random': 0.4166666666666667, 'Accuracy_Name_AccuracyPerObject': [0.3, 0.3, 0.5, 0.5, 0.4, 0.0], 'Accuracy_Category_AccuracyPerObject': [0.7333333333333333, 0.73
# ...

# %%
pp.AccPerObj_auto_plot(original_results=original_results, saving_address='C:\\Users\Sakai Lab\Desktop\Graph\AccPerObj')
plt.close('all')
