# %%
import Window_Size

import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
# %matplotlib qt5
# %load_ext autoreload
# %autoreload 2
import numpy as np

import Post_Processing
pp = Post_Processing.PP()

# %%
original_results = pp.read_file(fileName='saved results\\1010_classifiers.pkl')

# %%
print(original_results)
# Out:
# {'BASE': [[{'Menu': {'windowSize': 20, 'getRawData': 'no', 'doublingData': 'no', 'rangeOption': '0', 'avgTrials': 'no', 'avgNum': '4', 'normType': 'sk', 'turnOnMeanRemoval': 'no', 'turnOnSliceWindow': 'yes', 'sliceWindowType': 'cf', 'cfDegree': '1', 'turnOnPga': 'no', 'newTDT': 'clustered1', 'pcaOn': 'no', 'pcaComponents': '0.9'}, 'Accuracy_Name_linear': 0.36666666666666664, 'Accuracy_Category_linear': 0.7333333333333333, 'Accuracy_Name_rbf': 0.26666666666666666, 'Accuracy_Category_rbf': 0.6166666666666667, 'Accuracy_Name_lda': 0.3, 'Accuracy_Category_lda': 0.6833333333333333, 'Accuracy_Name_rvm': 0.2833333333333333, 'Accuracy_Category_rvm': 0.6833333333333333, 'Accuracy_Name_gnb': 0.23333333333333334, 'Accuracy_Category_gnb': 0.7166666666666667}, {'Menu': {'windowSize': 20, 'getRawData': 'no', 'doublingData': 'no', 'rangeOption': '0', 'avgTrials': 'no', 'avgNum': '4', 'normType': 'sk', 'turnOnMeanRemoval': 'no', 'turnOnSliceWindow': 'yes', 'sliceWindowType': 'cf', 'cfDegree': '1', '
# ...

# %%
pp.create_table(results=original_results, dataType='base')
# Out:
# ╒═════════════════╤══════════════╤═══════════╤═══════╤═══════╤═══════╕
# │                 │   Linear SVM │   RBF SVM │   RVM │   LDA │   GNB │
# ╞═════════════════╪══════════════╪═══════════╪═══════╪═══════╪═══════╡
# │ Stage1-Object   │        0.315 │     0.233 │ 0.197 │ 0.25  │ 0.276 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# │ Stage1-Category │        0.667 │     0.608 │ 0.634 │ 0.608 │ 0.553 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# │ Stage2-Object   │        0.172 │     0.169 │ 0.158 │ 0.162 │ 0.161 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# │ Stage2-Category │        0.517 │     0.517 │ 0.502 │ 0.523 │ 0.531 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# │ Stage3-Object   │        0.189 │     0.164 │ 0.139 │ 0.165 │ 0.155 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# ...

# %%
pp.create_table(results=original_results, dataType='pga')
# Out:
# ╒═════════════════╤══════════════╤═══════════╤═══════╤═══════╤═══════╕
# │                 │   Linear SVM │   RBF SVM │   RVM │   LDA │   GNB │
# ╞═════════════════╪══════════════╪═══════════╪═══════╪═══════╪═══════╡
# │ Stage1-Object   │        0.953 │     0.901 │ 0.314 │ 0.931 │ 0.952 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# │ Stage1-Category │        0.972 │     0.969 │ 0.979 │ 0.94  │ 0.951 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# │ Stage2-Object   │        0.902 │     0.864 │ 0.275 │ 0.927 │ 0.973 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# │ Stage2-Category │        0.911 │     0.896 │ 0.91  │ 0.928 │ 0.904 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# │ Stage3-Object   │        0.951 │     0.934 │ 0.307 │ 0.946 │ 0.992 │
# ├─────────────────┼──────────────┼───────────┼───────┼───────┼───────┤
# ...
