# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
# %matplotlib qt5
# %load_ext autoreload
# %autoreload 2
import numpy as np

import Post_Processing
pp = Post_Processing.PP()

# %%
original_results = pp.read_file(fileName='1009_classifiers.pkl')

# %%
original_results
# Out:
# {'BASE': [[{'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.3333333333333333,
#     'Accuracy_Category_linear': 0.7,
#     'Accuracy_Name_rbf': 0.23333333333333334,
#     'Accuracy_Category_rbf': 0.6,
#     'Accuracy_Name_lda': 0.31666666666666665,
#     'Accuracy_Category_lda': 0.6666666666666666,
#     'Accuracy_Name_rvm': 0.25,
#     'Accuracy_Category_rvm': 0.6666666666666666,
#     'Accuracy_Name_gnb': 0.25,
#     'Accuracy_Category_gnb': 0.7},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.3333333333333333,
#     'Accuracy_Category_linear': 0.7894736842105263,
#     'Accuracy_Name_rbf': 0.15789473684210525,
#     'Accuracy_Category_rbf': 0.49122807017543857,
#     'Accuracy_Name_lda': 0.3333333333333333,
#     'Accuracy_Category_lda': 0.6666666666666666,
#     'Accuracy_Name_rvm': 0.07017543859649122,
#     'Accuracy_Category_rvm': 0.6140350877192983,
#     'Accuracy_Name_gnb': 0.3333333333333333,
#     'Accuracy_Category_gnb': 0.5614035087719298},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.4444444444444444,
#     'Accuracy_Category_linear': 0.8703703703703703,
#     'Accuracy_Name_rbf': 0.37037037037037035,
#     'Accuracy_Category_rbf': 0.7222222222222222,
#     'Accuracy_Name_lda': 0.2962962962962963,
#     'Accuracy_Category_lda': 0.7407407407407407,
#     'Accuracy_Name_rvm': 0.2777777777777778,
#     'Accuracy_Category_rvm': 0.8518518518518519,
#     'Accuracy_Name_gnb': 0.46296296296296297,
#     'Accuracy_Category_gnb': 0.6851851851851852},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.2127659574468085,
#     'Accuracy_Category_linear': 0.46808510638297873,
#     'Accuracy_Name_rbf': 0.23404255319148937,
#     'Accuracy_Category_rbf': 0.44680851063829785,
#     'Accuracy_Name_lda': 0.2127659574468085,
#     'Accuracy_Category_lda': 0.3829787234042553,
#     'Accuracy_Name_rvm': 0.1276595744680851,
#     'Accuracy_Category_rvm': 0.5106382978723404,
#     'Accuracy_Name_gnb': 0.2553191489361702,
#     'Accuracy_Category_gnb': 0.46808510638297873},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.16363636363636364,
#     'Accuracy_Category_linear': 0.43636363636363634,
#     'Accuracy_Name_rbf': 0.16363636363636364,
#     'Accuracy_Category_rbf': 0.5636363636363636,
#     'Accuracy_Name_lda': 0.18181818181818182,
#     'Accuracy_Category_lda': 0.4727272727272727,
#     'Accuracy_Name_rvm': 0.12727272727272726,
#     'Accuracy_Category_rvm': 0.5272727272727272,
#     'Accuracy_Name_gnb': 0.12727272727272726,
#     'Accuracy_Category_gnb': 0.4727272727272727},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.3275862068965517,
#     'Accuracy_Category_linear': 0.6896551724137931,
#     'Accuracy_Name_rbf': 0.13793103448275862,
#     'Accuracy_Category_rbf': 0.5689655172413793,
#     'Accuracy_Name_lda': 0.29310344827586204,
#     'Accuracy_Category_lda': 0.6379310344827587,
#     'Accuracy_Name_rvm': 0.20689655172413793,
#     'Accuracy_Category_rvm': 0.5862068965517241,
#     'Accuracy_Name_gnb': 0.2413793103448276,
#     'Accuracy_Category_gnb': 0.5344827586206896},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.3333333333333333,
#     'Accuracy_Category_linear': 0.75,
#     'Accuracy_Name_rbf': 0.21666666666666667,
#     'Accuracy_Category_rbf': 0.7166666666666667,
#     'Accuracy_Name_lda': 0.35,
#     'Accuracy_Category_lda': 0.7333333333333333,
#     'Accuracy_Name_rvm': 0.2,
#     'Accuracy_Category_rvm': 0.7,
#     'Accuracy_Name_gnb': 0.18333333333333332,
#     'Accuracy_Category_gnb': 0.5833333333333334}],
#   [{'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.25,
#     'Accuracy_Category_linear': 0.55,
#     'Accuracy_Name_rbf': 0.23333333333333334,
#     'Accuracy_Category_rbf': 0.5166666666666667,
#     'Accuracy_Name_lda': 0.25,
#     'Accuracy_Category_lda': 0.5333333333333333,
#     'Accuracy_Name_rvm': 0.18333333333333332,
#     'Accuracy_Category_rvm': 0.55,
#     'Accuracy_Name_gnb': 0.21666666666666667,
#     'Accuracy_Category_gnb': 0.5666666666666667},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.1896551724137931,
#     'Accuracy_Category_linear': 0.5,
#     'Accuracy_Name_rbf': 0.1206896551724138,
#     'Accuracy_Category_rbf': 0.5344827586206896,
#     'Accuracy_Name_lda': 0.13793103448275862,
#     'Accuracy_Category_lda': 0.5172413793103449,
#     'Accuracy_Name_rvm': 0.1896551724137931,
#     'Accuracy_Category_rvm': 0.5517241379310345,
#     'Accuracy_Name_gnb': 0.1896551724137931,
#     'Accuracy_Category_gnb': 0.5517241379310345},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.2037037037037037,
#     'Accuracy_Category_linear': 0.5370370370370371,
#     'Accuracy_Name_rbf': 0.14814814814814814,
#     'Accuracy_Category_rbf': 0.5185185185185185,
#     'Accuracy_Name_lda': 0.16666666666666666,
#     'Accuracy_Category_lda': 0.5,
#     'Accuracy_Name_rvm': 0.18518518518518517,
#     'Accuracy_Category_rvm': 0.5370370370370371,
#     'Accuracy_Name_gnb': 0.14814814814814814,
#     'Accuracy_Category_gnb': 0.6111111111111112},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.1702127659574468,
#     'Accuracy_Category_linear': 0.5106382978723404,
#     'Accuracy_Name_rbf': 0.1276595744680851,
#     'Accuracy_Category_rbf': 0.425531914893617,
#     'Accuracy_Name_lda': 0.14893617021276595,
#     'Accuracy_Category_lda': 0.5106382978723404,
#     'Accuracy_Name_rvm': 0.19148936170212766,
#     'Accuracy_Category_rvm': 0.44680851063829785,
#     'Accuracy_Name_gnb': 0.14893617021276595,
#     'Accuracy_Category_gnb': 0.5319148936170213},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.15789473684210525,
#     'Accuracy_Category_linear': 0.47368421052631576,
#     'Accuracy_Name_rbf': 0.12280701754385964,
#     'Accuracy_Category_rbf': 0.45614035087719296,
#     'Accuracy_Name_lda': 0.12280701754385964,
#     'Accuracy_Category_lda': 0.5087719298245614,
#     'Accuracy_Name_rvm': 0.14035087719298245,
#     'Accuracy_Category_rvm': 0.3684210526315789,
#     'Accuracy_Name_gnb': 0.14035087719298245,
#     'Accuracy_Category_gnb': 0.47368421052631576},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.13793103448275862,
#     'Accuracy_Category_linear': 0.5344827586206896,
#     'Accuracy_Name_rbf': 0.22413793103448276,
#     'Accuracy_Category_rbf': 0.5517241379310345,
#     'Accuracy_Name_lda': 0.27586206896551724,
#     'Accuracy_Category_lda': 0.5,
#     'Accuracy_Name_rvm': 0.10344827586206896,
#     'Accuracy_Category_rvm': 0.5172413793103449,
#     'Accuracy_Name_gnb': 0.15517241379310345,
#     'Accuracy_Category_gnb': 0.43103448275862066},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.1,
#     'Accuracy_Category_linear': 0.5833333333333334,
#     'Accuracy_Name_rbf': 0.21666666666666667,
#     'Accuracy_Category_rbf': 0.5666666666666667,
#     'Accuracy_Name_lda': 0.2,
#     'Accuracy_Category_lda': 0.55,
#     'Accuracy_Name_rvm': 0.21666666666666667,
#     'Accuracy_Category_rvm': 0.5666666666666667,
#     'Accuracy_Name_gnb': 0.16666666666666666,
#     'Accuracy_Category_gnb': 0.55}],
#   [{'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.26666666666666666,
#     'Accuracy_Category_linear': 0.55,
#     'Accuracy_Name_rbf': 0.16666666666666666,
#     'Accuracy_Category_rbf': 0.45,
#     'Accuracy_Name_lda': 0.16666666666666666,
#     'Accuracy_Category_lda': 0.45,
#     'Accuracy_Name_rvm': 0.13333333333333333,
#     'Accuracy_Category_rvm': 0.55,
#     'Accuracy_Name_gnb': 0.15,
#     'Accuracy_Category_gnb': 0.4},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.1724137931034483,
#     'Accuracy_Category_linear': 0.5172413793103449,
#     'Accuracy_Name_rbf': 0.15517241379310345,
#     'Accuracy_Category_rbf': 0.4827586206896552,
#     'Accuracy_Name_lda': 0.08620689655172414,
#     'Accuracy_Category_lda': 0.43103448275862066,
#     'Accuracy_Name_rvm': 0.1896551724137931,
#     'Accuracy_Category_rvm': 0.4827586206896552,
#     'Accuracy_Name_gnb': 0.22413793103448276,
#     'Accuracy_Category_gnb': 0.4482758620689655},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.16666666666666666,
#     'Accuracy_Category_linear': 0.5370370370370371,
#     'Accuracy_Name_rbf': 0.2037037037037037,
#     'Accuracy_Category_rbf': 0.5185185185185185,
#     'Accuracy_Name_lda': 0.14814814814814814,
#     'Accuracy_Category_lda': 0.5740740740740741,
#     'Accuracy_Name_rvm': 0.1111111111111111,
#     'Accuracy_Category_rvm': 0.5370370370370371,
#     'Accuracy_Name_gnb': 0.14814814814814814,
#     'Accuracy_Category_gnb': 0.5370370370370371},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.25,
#     'Accuracy_Category_linear': 0.5625,
#     'Accuracy_Name_rbf': 0.2708333333333333,
#     'Accuracy_Category_rbf': 0.5,
#     'Accuracy_Name_lda': 0.16666666666666666,
#     'Accuracy_Category_lda': 0.4791666666666667,
#     'Accuracy_Name_rvm': 0.125,
#     'Accuracy_Category_rvm': 0.4166666666666667,
#     'Accuracy_Name_gnb': 0.16666666666666666,
#     'Accuracy_Category_gnb': 0.4791666666666667},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.23214285714285715,
#     'Accuracy_Category_linear': 0.39285714285714285,
#     'Accuracy_Name_rbf': 0.21428571428571427,
#     'Accuracy_Category_rbf': 0.5,
#     'Accuracy_Name_lda': 0.17857142857142858,
#     'Accuracy_Category_lda': 0.39285714285714285,
#     'Accuracy_Name_rvm': 0.125,
#     'Accuracy_Category_rvm': 0.48214285714285715,
#     'Accuracy_Name_gnb': 0.21428571428571427,
#     'Accuracy_Category_gnb': 0.5357142857142857},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.0847457627118644,
#     'Accuracy_Category_linear': 0.4576271186440678,
#     'Accuracy_Name_rbf': 0.1016949152542373,
#     'Accuracy_Category_rbf': 0.4406779661016949,
#     'Accuracy_Name_lda': 0.0847457627118644,
#     'Accuracy_Category_lda': 0.559322033898305,
#     'Accuracy_Name_rvm': 0.13559322033898305,
#     'Accuracy_Category_rvm': 0.4406779661016949,
#     'Accuracy_Name_gnb': 0.0847457627118644,
#     'Accuracy_Category_gnb': 0.3389830508474576},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.18333333333333332,
#     'Accuracy_Category_linear': 0.5,
#     'Accuracy_Name_rbf': 0.1,
#     'Accuracy_Category_rbf': 0.43333333333333335,
#     'Accuracy_Name_lda': 0.08333333333333333,
#     'Accuracy_Category_lda': 0.55,
#     'Accuracy_Name_rvm': 0.16666666666666666,
#     'Accuracy_Category_rvm': 0.48333333333333334,
#     'Accuracy_Name_gnb': 0.08333333333333333,
#     'Accuracy_Category_gnb': 0.45}],
#   [{'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.31666666666666665,
#     'Accuracy_Category_linear': 0.5166666666666667,
#     'Accuracy_Name_rbf': 0.3333333333333333,
#     'Accuracy_Category_rbf': 0.6,
#     'Accuracy_Name_lda': 0.23333333333333334,
#     'Accuracy_Category_lda': 0.6,
#     'Accuracy_Name_rvm': 0.2,
#     'Accuracy_Category_rvm': 0.55,
#     'Accuracy_Name_gnb': 0.2833333333333333,
#     'Accuracy_Category_gnb': 0.48333333333333334},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.1864406779661017,
#     'Accuracy_Category_linear': 0.5084745762711864,
#     'Accuracy_Name_rbf': 0.22033898305084745,
#     'Accuracy_Category_rbf': 0.576271186440678,
#     'Accuracy_Name_lda': 0.22033898305084745,
#     'Accuracy_Category_lda': 0.4576271186440678,
#     'Accuracy_Name_rvm': 0.22033898305084745,
#     'Accuracy_Category_rvm': 0.5084745762711864,
#     'Accuracy_Name_gnb': 0.23728813559322035,
#     'Accuracy_Category_gnb': 0.5423728813559322},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.18518518518518517,
#     'Accuracy_Category_linear': 0.42592592592592593,
#     'Accuracy_Name_rbf': 0.2777777777777778,
#     'Accuracy_Category_rbf': 0.5,
#     'Accuracy_Name_lda': 0.14814814814814814,
#     'Accuracy_Category_lda': 0.42592592592592593,
#     'Accuracy_Name_rvm': 0.2037037037037037,
#     'Accuracy_Category_rvm': 0.5185185185185185,
#     'Accuracy_Name_gnb': 0.18518518518518517,
#     'Accuracy_Category_gnb': 0.46296296296296297},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.17391304347826086,
#     'Accuracy_Category_linear': 0.5217391304347826,
#     'Accuracy_Name_rbf': 0.17391304347826086,
#     'Accuracy_Category_rbf': 0.5869565217391305,
#     'Accuracy_Name_lda': 0.13043478260869565,
#     'Accuracy_Category_lda': 0.5217391304347826,
#     'Accuracy_Name_rvm': 0.15217391304347827,
#     'Accuracy_Category_rvm': 0.5,
#     'Accuracy_Name_gnb': 0.08695652173913043,
#     'Accuracy_Category_gnb': 0.5},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.23636363636363636,
#     'Accuracy_Category_linear': 0.5454545454545454,
#     'Accuracy_Name_rbf': 0.14545454545454545,
#     'Accuracy_Category_rbf': 0.41818181818181815,
#     'Accuracy_Name_lda': 0.2727272727272727,
#     'Accuracy_Category_lda': 0.6181818181818182,
#     'Accuracy_Name_rvm': 0.16363636363636364,
#     'Accuracy_Category_rvm': 0.45454545454545453,
#     'Accuracy_Name_gnb': 0.2,
#     'Accuracy_Category_gnb': 0.5454545454545454},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.13559322033898305,
#     'Accuracy_Category_linear': 0.576271186440678,
#     'Accuracy_Name_rbf': 0.15254237288135594,
#     'Accuracy_Category_rbf': 0.5423728813559322,
#     'Accuracy_Name_lda': 0.2033898305084746,
#     'Accuracy_Category_lda': 0.6271186440677966,
#     'Accuracy_Name_rvm': 0.2033898305084746,
#     'Accuracy_Category_rvm': 0.4576271186440678,
#     'Accuracy_Name_gnb': 0.15254237288135594,
#     'Accuracy_Category_gnb': 0.576271186440678},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.23333333333333334,
#     'Accuracy_Category_linear': 0.4166666666666667,
#     'Accuracy_Name_rbf': 0.15,
#     'Accuracy_Category_rbf': 0.5,
#     'Accuracy_Name_lda': 0.11666666666666667,
#     'Accuracy_Category_lda': 0.5166666666666667,
#     'Accuracy_Name_rvm': 0.11666666666666667,
#     'Accuracy_Category_rvm': 0.43333333333333335,
#     'Accuracy_Name_gnb': 0.11666666666666667,
#     'Accuracy_Category_gnb': 0.4666666666666667}]],
#  'PGA': [[{'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9985632183908046,
#     'Accuracy_Category_linear': 0.992816091954023,
#     'Accuracy_Name_rbf': 0.9899425287356322,
#     'Accuracy_Category_rbf': 0.9899425287356322,
#     'Accuracy_Name_lda': 0.9971264367816092,
#     'Accuracy_Category_lda': 0.9985632183908046,
#     'Accuracy_Name_rvm': 0.38362068965517243,
#     'Accuracy_Category_rvm': 0.9942528735632183,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.9626436781609196},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9663299663299664,
#     'Accuracy_Category_linear': 0.9781144781144782,
#     'Accuracy_Name_rbf': 0.8552188552188552,
#     'Accuracy_Category_rbf': 0.9713804713804713,
#     'Accuracy_Name_lda': 0.9158249158249159,
#     'Accuracy_Category_lda': 0.9040404040404041,
#     'Accuracy_Name_rvm': 0.23905723905723905,
#     'Accuracy_Category_rvm': 0.9797979797979798,
#     'Accuracy_Name_gnb': 0.9343434343434344,
#     'Accuracy_Category_gnb': 0.9595959595959596},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 1.0,
#     'Accuracy_Category_linear': 0.9976851851851852,
#     'Accuracy_Name_rbf': 1.0,
#     'Accuracy_Category_rbf': 0.9652777777777778,
#     'Accuracy_Name_lda': 0.9629629629629629,
#     'Accuracy_Category_lda': 0.9652777777777778,
#     'Accuracy_Name_rvm': 0.24768518518518517,
#     'Accuracy_Category_rvm': 0.9976851851851852,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.9722222222222222},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9397163120567376,
#     'Accuracy_Category_linear': 0.9680851063829787,
#     'Accuracy_Name_rbf': 0.8794326241134752,
#     'Accuracy_Category_rbf': 0.9609929078014184,
#     'Accuracy_Name_lda': 0.900709219858156,
#     'Accuracy_Category_lda': 0.875886524822695,
#     'Accuracy_Name_rvm': 0.2872340425531915,
#     'Accuracy_Category_rvm': 0.975177304964539,
#     'Accuracy_Name_gnb': 0.9893617021276596,
#     'Accuracy_Category_gnb': 0.9219858156028369},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.8265993265993266,
#     'Accuracy_Category_linear': 0.9545454545454546,
#     'Accuracy_Name_rbf': 0.5589225589225589,
#     'Accuracy_Category_rbf': 0.8754208754208754,
#     'Accuracy_Name_lda': 0.8703703703703703,
#     'Accuracy_Category_lda': 0.9494949494949495,
#     'Accuracy_Name_rvm': 0.3872053872053872,
#     'Accuracy_Category_rvm': 0.9696969696969697,
#     'Accuracy_Name_gnb': 0.7727272727272727,
#     'Accuracy_Category_gnb': 0.968013468013468},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9831649831649831,
#     'Accuracy_Category_linear': 0.9781144781144782,
#     'Accuracy_Name_rbf': 0.898989898989899,
#     'Accuracy_Category_rbf': 0.9696969696969697,
#     'Accuracy_Name_lda': 0.9545454545454546,
#     'Accuracy_Category_lda': 0.9865319865319865,
#     'Accuracy_Name_rvm': 0.27946127946127947,
#     'Accuracy_Category_rvm': 0.9781144781144782,
#     'Accuracy_Name_gnb': 0.9713804713804713,
#     'Accuracy_Category_gnb': 0.9663299663299664},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9745762711864406,
#     'Accuracy_Category_linear': 0.9759887005649718,
#     'Accuracy_Name_rbf': 0.8573446327683616,
#     'Accuracy_Category_rbf': 0.943502824858757,
#     'Accuracy_Name_lda': 0.8050847457627118,
#     'Accuracy_Category_lda': 0.8686440677966102,
#     'Accuracy_Name_rvm': 0.3375706214689266,
#     'Accuracy_Category_rvm': 0.980225988700565,
#     'Accuracy_Name_gnb': 0.9562146892655368,
#     'Accuracy_Category_gnb': 0.9307909604519774}],
#   [{'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 1.0,
#     'Accuracy_Category_linear': 0.9823232323232324,
#     'Accuracy_Name_rbf': 0.9709595959595959,
#     'Accuracy_Category_rbf': 0.9772727272727273,
#     'Accuracy_Name_lda': 0.9987373737373737,
#     'Accuracy_Category_lda': 0.88510101010101,
#     'Accuracy_Name_rvm': 0.29292929292929293,
#     'Accuracy_Category_rvm': 0.9911616161616161,
#     'Accuracy_Name_gnb': 0.976010101010101,
#     'Accuracy_Category_gnb': 0.8472222222222222},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.900990099009901,
#     'Accuracy_Category_linear': 0.9158415841584159,
#     'Accuracy_Name_rbf': 0.7920792079207921,
#     'Accuracy_Category_rbf': 0.8547854785478548,
#     'Accuracy_Name_lda': 0.8036303630363036,
#     'Accuracy_Category_lda': 0.83003300330033,
#     'Accuracy_Name_rvm': 0.1617161716171617,
#     'Accuracy_Category_rvm': 0.8910891089108911,
#     'Accuracy_Name_gnb': 0.8729372937293729,
#     'Accuracy_Category_gnb': 0.8696369636963697},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 1.0,
#     'Accuracy_Category_linear': 0.9789272030651341,
#     'Accuracy_Name_rbf': 0.9712643678160919,
#     'Accuracy_Category_rbf': 0.9674329501915708,
#     'Accuracy_Name_lda': 0.9597701149425287,
#     'Accuracy_Category_lda': 0.9348659003831418,
#     'Accuracy_Name_rvm': 0.3544061302681992,
#     'Accuracy_Category_rvm': 0.9846743295019157,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.9674329501915708},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.7333333333333333,
#     'Accuracy_Category_linear': 0.6888888888888889,
#     'Accuracy_Name_rbf': 0.6074074074074074,
#     'Accuracy_Category_rbf': 0.6148148148148148,
#     'Accuracy_Name_lda': 0.8,
#     'Accuracy_Category_lda': 0.8592592592592593,
#     'Accuracy_Name_rvm': 0.15555555555555556,
#     'Accuracy_Category_rvm': 0.6777777777777778,
#     'Accuracy_Name_gnb': 0.9962962962962963,
#     'Accuracy_Category_gnb': 0.937037037037037},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.8410852713178295,
#     'Accuracy_Category_linear': 0.877906976744186,
#     'Accuracy_Name_rbf': 0.622093023255814,
#     'Accuracy_Category_rbf': 0.8527131782945736,
#     'Accuracy_Name_lda': 0.939922480620155,
#     'Accuracy_Category_lda': 0.8837209302325582,
#     'Accuracy_Name_rvm': 0.27906976744186046,
#     'Accuracy_Category_rvm': 0.8817829457364341,
#     'Accuracy_Name_gnb': 0.9515503875968992,
#     'Accuracy_Category_gnb': 0.8662790697674418},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.8966666666666666,
#     'Accuracy_Category_linear': 0.9633333333333334,
#     'Accuracy_Name_rbf': 0.8366666666666667,
#     'Accuracy_Category_rbf': 0.9516666666666667,
#     'Accuracy_Name_lda': 0.945,
#     'Accuracy_Category_lda': 0.98,
#     'Accuracy_Name_rvm': 0.2633333333333333,
#     'Accuracy_Category_rvm': 0.9716666666666667,
#     'Accuracy_Name_gnb': 0.995,
#     'Accuracy_Category_gnb': 0.9516666666666667},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9540229885057471,
#     'Accuracy_Category_linear': 0.9698275862068966,
#     'Accuracy_Name_rbf': 0.9295977011494253,
#     'Accuracy_Category_rbf': 0.9841954022988506,
#     'Accuracy_Name_lda': 0.9727011494252874,
#     'Accuracy_Category_lda': 0.9870689655172413,
#     'Accuracy_Name_rvm': 0.34051724137931033,
#     'Accuracy_Category_rvm': 0.9870689655172413,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.9281609195402298}],
#   [{'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 1.0,
#     'Accuracy_Category_linear': 1.0,
#     'Accuracy_Name_rbf': 1.0,
#     'Accuracy_Category_rbf': 0.9963235294117647,
#     'Accuracy_Name_lda': 0.9656862745098039,
#     'Accuracy_Category_lda': 0.9889705882352942,
#     'Accuracy_Name_rvm': 0.42892156862745096,
#     'Accuracy_Category_rvm': 1.0,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.9313725490196079},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9405940594059405,
#     'Accuracy_Category_linear': 0.905940594059406,
#     'Accuracy_Name_rbf': 0.9438943894389439,
#     'Accuracy_Category_rbf': 0.9323432343234324,
#     'Accuracy_Name_lda': 0.905940594059406,
#     'Accuracy_Category_lda': 0.8993399339933993,
#     'Accuracy_Name_rvm': 0.2755775577557756,
#     'Accuracy_Category_rvm': 0.9240924092409241,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.8844884488448845},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.998062015503876,
#     'Accuracy_Category_linear': 1.0,
#     'Accuracy_Name_rbf': 0.9786821705426356,
#     'Accuracy_Category_rbf': 0.9903100775193798,
#     'Accuracy_Name_lda': 0.9689922480620154,
#     'Accuracy_Category_lda': 0.9263565891472868,
#     'Accuracy_Name_rvm': 0.35658914728682173,
#     'Accuracy_Category_rvm': 0.9961240310077519,
#     'Accuracy_Name_gnb': 0.9941860465116279,
#     'Accuracy_Category_gnb': 0.9670542635658915},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.8518518518518519,
#     'Accuracy_Category_linear': 0.9691358024691358,
#     'Accuracy_Name_rbf': 0.7407407407407407,
#     'Accuracy_Category_rbf': 0.8765432098765432,
#     'Accuracy_Name_lda': 0.8333333333333334,
#     'Accuracy_Category_lda': 0.8209876543209876,
#     'Accuracy_Name_rvm': 0.24691358024691357,
#     'Accuracy_Category_rvm': 0.9722222222222222,
#     'Accuracy_Name_gnb': 0.9475308641975309,
#     'Accuracy_Category_gnb': 0.9814814814814815},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9337899543378996,
#     'Accuracy_Category_linear': 0.9178082191780822,
#     'Accuracy_Name_rbf': 0.8036529680365296,
#     'Accuracy_Category_rbf': 0.8812785388127854,
#     'Accuracy_Name_lda': 0.9634703196347032,
#     'Accuracy_Category_lda': 0.9337899543378996,
#     'Accuracy_Name_rvm': 0.18493150684931506,
#     'Accuracy_Category_rvm': 0.9178082191780822,
#     'Accuracy_Name_gnb': 0.9954337899543378,
#     'Accuracy_Category_gnb': 0.954337899543379},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9579124579124579,
#     'Accuracy_Category_linear': 0.9545454545454546,
#     'Accuracy_Name_rbf': 0.9326599326599326,
#     'Accuracy_Category_rbf': 0.9259259259259259,
#     'Accuracy_Name_lda': 0.9511784511784511,
#     'Accuracy_Category_lda': 0.9242424242424242,
#     'Accuracy_Name_rvm': 0.26262626262626265,
#     'Accuracy_Category_rvm': 0.9545454545454546,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.9057239057239057},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '2',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9597701149425287,
#     'Accuracy_Category_linear': 0.9554597701149425,
#     'Accuracy_Name_rbf': 0.9655172413793104,
#     'Accuracy_Category_rbf': 0.9238505747126436,
#     'Accuracy_Name_lda': 0.9238505747126436,
#     'Accuracy_Category_lda': 0.8908045977011494,
#     'Accuracy_Name_rvm': 0.22557471264367815,
#     'Accuracy_Category_rvm': 0.9568965517241379,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.9037356321839081}],
#   [{'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9722222222222222,
#     'Accuracy_Category_linear': 0.9987373737373737,
#     'Accuracy_Name_rbf': 0.9696969696969697,
#     'Accuracy_Category_rbf': 0.9696969696969697,
#     'Accuracy_Name_lda': 0.9696969696969697,
#     'Accuracy_Category_lda': 0.98989898989899,
#     'Accuracy_Name_rvm': 0.3194444444444444,
#     'Accuracy_Category_rvm': 0.9709595959595959,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.8977272727272727},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.8979591836734694,
#     'Accuracy_Category_linear': 0.9795918367346939,
#     'Accuracy_Name_rbf': 0.8163265306122449,
#     'Accuracy_Category_rbf': 0.967687074829932,
#     'Accuracy_Name_lda': 0.7551020408163265,
#     'Accuracy_Category_lda': 0.9013605442176871,
#     'Accuracy_Name_rvm': 0.31462585034013607,
#     'Accuracy_Category_rvm': 0.9829931972789115,
#     'Accuracy_Name_gnb': 0.9659863945578231,
#     'Accuracy_Category_gnb': 0.9115646258503401},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9411764705882353,
#     'Accuracy_Category_linear': 0.888235294117647,
#     'Accuracy_Name_rbf': 0.9215686274509803,
#     'Accuracy_Category_rbf': 0.8509803921568627,
#     'Accuracy_Name_lda': 0.8862745098039215,
#     'Accuracy_Category_lda': 0.8823529411764706,
#     'Accuracy_Name_rvm': 0.1803921568627451,
#     'Accuracy_Category_rvm': 0.8823529411764706,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.8392156862745098},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.937037037037037,
#     'Accuracy_Category_linear': 0.9518518518518518,
#     'Accuracy_Name_rbf': 0.8555555555555555,
#     'Accuracy_Category_rbf': 0.9037037037037037,
#     'Accuracy_Name_lda': 0.8888888888888888,
#     'Accuracy_Category_lda': 0.937037037037037,
#     'Accuracy_Name_rvm': 0.3,
#     'Accuracy_Category_rvm': 0.9333333333333333,
#     'Accuracy_Name_gnb': 0.9962962962962963,
#     'Accuracy_Category_gnb': 0.9296296296296296},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.8486590038314177,
#     'Accuracy_Category_linear': 0.9080459770114943,
#     'Accuracy_Name_rbf': 0.8084291187739464,
#     'Accuracy_Category_rbf': 0.8831417624521073,
#     'Accuracy_Name_lda': 0.9655172413793104,
#     'Accuracy_Category_lda': 0.946360153256705,
#     'Accuracy_Name_rvm': 0.19348659003831417,
#     'Accuracy_Category_rvm': 0.9176245210727969,
#     'Accuracy_Name_gnb': 0.9904214559386973,
#     'Accuracy_Category_gnb': 0.9003831417624522},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.8872053872053872,
#     'Accuracy_Category_linear': 0.9393939393939394,
#     'Accuracy_Name_rbf': 0.8232323232323232,
#     'Accuracy_Category_rbf': 0.8939393939393939,
#     'Accuracy_Name_lda': 0.8872053872053872,
#     'Accuracy_Category_lda': 0.9175084175084175,
#     'Accuracy_Name_rvm': 0.39225589225589225,
#     'Accuracy_Category_rvm': 0.9141414141414141,
#     'Accuracy_Name_gnb': 1.0,
#     'Accuracy_Category_gnb': 0.9259259259259259},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '3',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.9855072463768116,
#     'Accuracy_Category_linear': 0.9536231884057971,
#     'Accuracy_Name_rbf': 0.9391304347826087,
#     'Accuracy_Category_rbf': 0.9434782608695652,
#     'Accuracy_Name_lda': 0.9202898550724637,
#     'Accuracy_Category_lda': 0.9333333333333333,
#     'Accuracy_Name_rvm': 0.27246376811594203,
#     'Accuracy_Category_rvm': 0.9637681159420289,
#     'Accuracy_Name_gnb': 0.9985507246376811,
#     'Accuracy_Category_gnb': 0.9449275362318841}]]}

# %%
pp.create_bar_chart(results=original_results, classifier='linear', saving_address='C:\\Users\Sakai Lab\Desktop\_test')
# Out:
# 0
