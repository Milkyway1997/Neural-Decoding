# %%
import Window_Size

import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
# %matplotlib qt5
# %load_ext autoreload
# %autoreload 2
import numpy as np

import Post_Processing
pp = Post_Processing.PP()

# %%
original_results = pp.read_file(fileName='saved results\day1115_cross_subjects_ver2.pkl')

# %%
original_results
# Out:
# {'BASE': [[{'Menu': {'windowSize': 20,
#      'getRawData': 'no',
#      'doublingData': 'no',
#      'stage': '1',
#      'rangeIndex': '-1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'baseOrFlip': 'base',
#      'turnOnPga': 'no',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name_linear': 0.3013698630136986,
#     'Accuracy_Category_linear': 0.5821917808219178,
#     'Accuracy_Name_NN': 0.2465753424657534,
#     'Accuracy_Category_NN': 0.5821917808219178},
#    {'Menu': {'windowSize': 20,
#      'getRawData': 'no',
#      'doublingData': 'no',
#      'stage': '1',
#      'rangeIndex': '-1',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
# ...

# %%
pp.create_bar_chart(results=original_results, classifier='linear', saving_address='C:\\Users\Sakai Lab\Desktop\Graph\cross_subjects')
plt.close('all')
