# %%
import Window_Size

import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
# %matplotlib qt5
# %load_ext autoreload
# %autoreload 2
import numpy as np

import Post_Processing
pp = Post_Processing.PP()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
original_results = pp.read_file(fileName='saved results\\1009_clustered1_all_stages_SlicingWindow.pkl')

# %%
original_results
# Out:
# [[[{'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name': 0.9985632183908046,
#     'Accuracy_Category': 0.992816091954023},
#    {'Menu': {'getRawData': 'no',
#      'doublingData': 'no',
#      'rangeOption': '0',
#      'avgTrials': 'no',
#      'avgNum': '4',
#      'normType': 'sk',
#      'turnOnMeanRemoval': 'no',
#      'turnOnSliceWindow': 'yes',
#      'sliceWindowType': 'cf',
#      'cfDegree': '1',
#      'turnOnPga': 'yes',
#      'newTDT': 'clustered1',
#      'pcaOn': 'no',
#      'pcaComponents': '0.9'},
#     'Accuracy_Name': 0.9579124579124579,
#     'Accuracy_Category': 0.9831649831649831},
# ...

# %%
pp.auto_graph_saving(original_results=original_results, stage=0, total_subject_number=7, saving_address='C:\\Users\Sakai Lab\Desktop\Graph\Slicing Window\PGA\stage1', x_str={'value': 10, 'length': 20})
plt.close('all')

# %%
pp.auto_graph_saving(original_results=original_results, stage=1, total_subject_number=7, saving_address='C:\\Users\Sakai Lab\Desktop\Graph\Slicing Window\PGA\stage2', x_str={'value': 10, 'length': 20})
plt.close('all')

# %%
pp.auto_graph_saving(original_results=original_results, stage=2, total_subject_number=7, saving_address='C:\\Users\Sakai Lab\Desktop\Graph\Slicing Window\PGA\stage3', x_str={'value': 10, 'length': 20})
plt.close('all')

# %%
pp.auto_graph_saving(original_results=original_results, stage=3, total_subject_number=7, saving_address='C:\\Users\Sakai Lab\Desktop\Graph\Slicing Window\PGA\stage4', x_str={'value': 10, 'length': 20})
plt.close('all')

# %%
original_results2 = pp.read_file(fileName='saved results\\1001_AvgTrials.pkl')

# %%
pp.create_graph_for_multi_layer(original_results=original_results2, sec_layer_length=5, stage=0, total_subject_number=7, address='C:\\Users\Sakai Lab\Desktop\Graph\Average Trials\stage1', x_str={'value': 10, 'length': 20})
plt.close('all')

# %%
original_results_base = pp.read_file(fileName='saved results\\1010_base_all_stages.pkl')

# %%
pp.auto_graph_saving(original_results=original_results_base, stage=0, total_subject_number=7, saving_address='C:\\Users\Sakai Lab\Desktop\Graph\Slicing Window\Base\Stage1', x_str={'value': 10, 'length': 20})
plt.close('all')

# %%
pp.auto_graph_saving(original_results=original_results_base, stage=1, total_subject_number=7, saving_address='C:\\Users\Sakai Lab\Desktop\Graph\Slicing Window\Base\Stage2', x_str={'value': 10, 'length': 20})
plt.close('all')

# %%
pp.auto_graph_saving(original_results=original_results_base, stage=2, total_subject_number=7, saving_address='C:\\Users\Sakai Lab\Desktop\Graph\Slicing Window\Base\Stage3', x_str={'value': 10, 'length': 20})
plt.close('all')

# %%
pp.auto_graph_saving(original_results=original_results_base, stage=3, total_subject_number=7, saving_address='C:\\Users\Sakai Lab\Desktop\Graph\Slicing Window\Base\Stage4', x_str={'value': 10, 'length': 20})
plt.close('all')
