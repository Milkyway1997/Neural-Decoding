# %%
import Window_Size

import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
# %matplotlib qt5
# %load_ext autoreload
# %autoreload 2

# %%
ws = Window_Size.window_size()
name_mean_lst_ws, name_std_lst_ws, cate_mean_lst_ws, cate_std_lst_ws, original_results_ws = ws.accuracy_by_window_size(classifier='linear-SVM', pgaOn='no')
# Out:
# --------------------------------------------------------------
# This is Stage 1
# --------------------------------------------------------------
# Script by Dmitry Patashov
# WU Script Version: 3.7.3
#
#                                                 Settings
# subject                                             1002
# badChannels                                     [18, 21]
# numberOfChannels                                      64
# eventChannels                           (64, 65, 66, 67)
# fullDump                                              no
# RawDataFiltration                                    yes
# cutoff_l                                             0.1
# cutoff_h                                              40
# DT                                                  auto
# DT_param                                            None
# epochTypes                [010, 011, 100, 101, 110, 111]
# resemple                                             yes
# ...

# %%
import pickle
with open('1030_flip_4stages_sw.pkl', 'wb') as file:
    # A new file will be created
    pickle.dump(original_results_ws, file)

# %%
name_mean_lst_ws
# Out:
# [[0.858821547335661,
#   0.8099111294172499,
#   0.8349038975938449,
#   0.8302218415335585],
#  [0.8560939428839186,
#   0.8216110505333195,
#   0.8374549180020081,
#   0.8227818239240493],
#  [0.8689607066793614,
#   0.838205177082267,
#   0.8560450685241952,
#   0.8602006838926515],
#  [0.8767530890633953,
#   0.8380755426513622,
#   0.8718988179725427,
#   0.8617049889710172],
#  [0.8730367692428934,
#   0.8069927815380956,
#   0.8268947360748312,
#   0.811919578279195],
#  [0.8535743209450588,
#   0.8074159066860923,
#   0.8225886266578843,
#   0.8263365840742406],
#  [0.8475272466796582,
#   0.8009023230612603,
#   0.7979882351667856,
#   0.8277275687003025],
#  [0.8103882052968819,
#   0.7665194718270365,
#   0.7977394282604268,
#   0.7851458579903678],
#  [0.7463918713909061,
#   0.730449186878503,
#   0.7533138195209249,
#   0.7498533958740297],
#  [0.7918302708162537,
#   0.7839478863458474,
#   0.7686384684401716,
#   0.7525049774865545],
#  [0.4850006592698796,
# ...
