# %%
import comparation_for_classifiers as cc

import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
# %matplotlib qt5
# %load_ext autoreload
# %autoreload 2

import pickle
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
classifiers = cc.Run(window_size=15)
output_lst_base = classifiers.main(pgaOn='no')
output_lst_pga = classifiers.main(pgaOn='yes')
# Out:
# Script by Dmitry Patashov
# WU Script Version: 3.7.1
#
#                                                 Settings
# subject                                             1002
# badChannels                                     [18, 21]
# numberOfChannels                                      64
# eventChannels                           (64, 65, 66, 67)
# fullDump                                              no
# RawDataFiltration                                    yes
# cutoff_l                                             0.1
# cutoff_h                                              40
# DT                                                  auto
# DT_param                                            None
# epochTypes                [010, 011, 100, 101, 110, 111]
# resemple                                             yes
# new_freq                                             500
# tmin                                                -0.2
# ...

# %%
save_dict = {'BASE': output_lst_base, 'PGA': output_lst_pga}

# %%
with open('1009_classifiers.pkl', 'wb') as file:
    # A new file will be created
    pickle.dump(save_dict, file)
